# %% [markdown]
# ## Selenium
#
# ##### 爬取搜狗圖片
# 1. 柯基KerGee：http://pic.sogou.com/pics?ie=utf8&p=40230504&interV=kKIOkrELjboMmLkElbkTkKIMkbELjbgQmLkElbcTkKILmrELjb8TkKIKmrELjbkI_65458625&query=%E6%9F%AF%E5%9F%BA&
#
# 2. 吉娃娃GeeWaWa：http://pic.sogou.com/pics?query=%BC%AA%CD%DE%CD%DE&di=2&_asf=pic.sogou.com&w=05009900&sut=3074&sst0=1511336873975
#
# 3. 馬爾濟斯Maltese：http://pic.sogou.com/pics?query=%F1R%A0%96%9D%FA%CB%B9&di=2&_asf=pic.sogou.com&w=05009900&sut=2430&sst0=1511338811892

# %%
# selenium

# 柯基KerGee

from selenium import webdriver
import time
import urllib
import os

# 存圖位置
local_path = '/Users/s960405s/pythonRepository/crawlerImage/KerGee'

# 爬取頁面網址 
url = 'http://pic.sogou.com/pics?ie=utf8&p=40230504&interV=kKIOkrELjboMmLkElbkTkKIMkbELjbgQmLkElbcTkKILmrELjb8TkKIKmrELjbkI_65458625&query=%E6%9F%AF%E5%9F%BA&'  
  
# 目標元素的xpath
xpath = '//div[@id="imgid"]/ul/li/a/img'
  
# 啟動chrome瀏覽器
chromeDriver = '/Users/s960405s/webDriverTool/chromedriver'
driver = webdriver.Chrome(chromeDriver) 
  
# 最大化窗口，因為每一次爬取只能看到視窗内的圖片  
driver.maximize_window()  
  
# 紀錄下載過的圖片網址，避免重複下載  
img_url_dic = {}  
  
# 瀏覽器打開爬取頁面
driver.get(url)  
  
# 模擬滾動視窗瀏覽更多圖片
pos = 0  
m = 0 # 圖片編號  
for i in range(100):  
    pos += i*500 # 每次下滾500  
    js = "document.documentElement.scrollTop=%d" % pos  
    driver.execute_script(js)  
    time.sleep(1)
    
    for element in driver.find_elements_by_xpath(xpath):
        img_url = element.get_attribute('src')
        
        # 保存圖片到指定路徑
        if img_url != None and not img_url in img_url_dic:
            img_url_dic[img_url] = ''  
            m += 1
            # print(img_url)
            ext = img_url.split('/')[-1]
            # print(ext)
            filename = str(m) + 'KerGee' + '_' + ext +'.jpg'
            print(filename)
            # 保存圖片
            urllib.request.urlretrieve(img_url, os.path.join(local_path , filename)) 
driver.close()
# Out:
# 1KerGee_03cfd80accc74f15.jpg
# 2KerGee_ff4d5133f458b621.jpg
# 3KerGee_4b271dcaef34f13f.jpg
# 4KerGee_9451e5113667257b.jpg
# 5KerGee_8e8d41896e0f2c01.jpg
# 6KerGee_84ddc2d9ffc1a128.jpg
# 7KerGee_aad83a31c5fdd509.jpg
# 8KerGee_87c193ec837e4a32.jpg
# 9KerGee_4b5550d303e8501d.jpg
# 10KerGee_911b6389eacd28d7.jpg
# 11KerGee_34ef46dc83e0bf39.jpg
# 12KerGee_2cff642f09a52762.jpg
# 13KerGee_ac4cd006c0b3f260.jpg
# 14KerGee_5c43f3e1da9dec6e.jpg
# 15KerGee_851fa348857c30b7.jpg
# 16KerGee_f73eb7137559667e.jpg
# 17KerGee_6f7da58c9e10dc60.jpg
# 18KerGee_b61d7aadc6a0edac.jpg
# 19KerGee_25870c2b5d36b0c8.jpg
# 20KerGee_a07d8db3d04962db.jpg
# 21KerGee_aff0f635358c2977.jpg
# 22KerGee_8ba51e25aae065bb.jpg
# 23KerGee_0a5288fd86273798.jpg
# 24KerGee_db2fd90ddab20f2b.jpg
# 25KerGee_180ee9a64a2132cf.jpg
# 26KerGee_9666e049a15ecb6b.jpg
# 27KerGee_41f88e6aefea8201.jpg
# 28KerGee_7191f35822029fc2.jpg
# 29KerGee_58bdb1928fccf52d.jpg
# 30KerGee_480cb3c6a9576e4a.jpg
# 31KerGee_dc825dc96c44631d.jpg
# ...

# %%
# 吉娃娃GeeWaWa

from selenium import webdriver
import time
import urllib
import os

# 存圖位置
local_path = '/Users/s960405s/pythonRepository/crawlerImage/GeeWaWa'

# 爬取頁面網址 
url = 'http://pic.sogou.com/pics?query=%BC%AA%CD%DE%CD%DE&di=2&_asf=pic.sogou.com&w=05009900&sut=3074&sst0=1511336873975'  
  
# 目標元素的xpath
xpath = '//div[@id="imgid"]/ul/li/a/img'
  
# 啟動chrome瀏覽器
chromeDriver = '/Users/s960405s/webDriverTool/chromedriver'
driver = webdriver.Chrome(chromeDriver) 
  
# 最大化窗口，因為每一次爬取只能看到視窗内的圖片  
driver.maximize_window()  
  
# 紀錄下載過的圖片網址，避免重複下載  
img_url_dic = {}  
  
# 瀏覽器打開爬取頁面
driver.get(url)  
  
# 模擬滾動視窗瀏覽更多圖片
pos = 0  
m = 0 # 圖片編號  
for i in range(100):  
    pos += i*500 # 每次下滾500  
    js = "document.documentElement.scrollTop=%d" % pos  
    driver.execute_script(js)  
    time.sleep(1)
    
    for element in driver.find_elements_by_xpath(xpath):
        img_url = element.get_attribute('src')
        
        # 保存圖片到指定路徑
        if img_url != None and not img_url in img_url_dic:
            img_url_dic[img_url] = ''  
            m += 1
            # print(img_url)
            ext = img_url.split('/')[-1]
            # print(ext)
            filename = str(m) + 'GeeWaWa' + '_' + ext +'.jpg'
            print(filename)
            # 保存圖片
            urllib.request.urlretrieve(img_url, os.path.join(local_path , filename)) 
driver.close()
# Out:
# 1GeeWaWa_b7c2f48c03d9324e-441219ec5e751595-7a95d4d7de350ad42679397671cf7fb1.jpg.jpg
# 2GeeWaWa_ac75323d6b6de243-503c0c74be6ae02f-b36ebc4578f2fffa3e7343a12b6c4dd8.jpg.jpg
# 3GeeWaWa_30c40e020f63f81f-c00171587126b6cf-c5bae56b3d3ae02e7ca4d5ab7813a910.jpg.jpg
# 4GeeWaWa_b7c2f48c03d9324e-441219ec5e751595-011276a40a5d19ce42b6a908f9419a32.jpg.jpg
# 5GeeWaWa_b7c2f48c03d9324e-441219ec5e751595-b4d07488697cc3e6afbc1282dce43c2d.jpg.jpg
# 6GeeWaWa_30c40e020f63f81f-04b690f202bc5258-000f67e957ed329894eb2b843b9e3423.jpg.jpg
# 7GeeWaWa_9b087f68ff374fe1-7dd4f5309749ea7a-dbea6cc93ec3e9e723224dc709f426ce.jpg.jpg
# 8GeeWaWa_b7c2f48c03d9324e-441219ec5e751595-ee7e182c5e390c9e31bf769c947f8c65.jpg.jpg
# 9GeeWaWa_2e6ac9045aedfb38-8f1161f3a636f237-ece7431fc63144e44a3d838f3f846cf9.jpg.jpg
# 10GeeWaWa_d763be601b248d56-a4350cff59817104-88e6f8f6178cfdb1cd0215e045a8416c.jpg.jpg
# 11GeeWaWa_f262f1cc86fb833a.jpg
# 12GeeWaWa_735a5186ee79dc25.jpg
# 13GeeWaWa_1cac7eeb4c17b91c.jpg
# 14GeeWaWa_c4ce8842fe75fecb.jpg
# ...

# %%
# 吉娃娃Maltese

from selenium import webdriver
import time
import urllib
import os

# 存圖位置
local_path = '/Users/s960405s/pythonRepository/crawlerImage/Maltese'

# 爬取頁面網址 
url = 'http://pic.sogou.com/pics?query=%F1R%A0%96%9D%FA%CB%B9&di=2&_asf=pic.sogou.com&w=05009900&sut=2430&sst0=1511338811892'  
  
# 目標元素的xpath
xpath = '//div[@id="imgid"]/ul/li/a/img'
  
# 啟動chrome瀏覽器
chromeDriver = '/Users/s960405s/webDriverTool/chromedriver'
driver = webdriver.Chrome(chromeDriver) 
  
# 最大化窗口，因為每一次爬取只能看到視窗内的圖片  
driver.maximize_window()  
  
# 紀錄下載過的圖片網址，避免重複下載  
img_url_dic = {}  
  
# 瀏覽器打開爬取頁面
driver.get(url)  
  
# 模擬滾動視窗瀏覽更多圖片
pos = 0  
m = 0 # 圖片編號  
for i in range(100):  
    pos += i*500 # 每次下滾500  
    js = "document.documentElement.scrollTop=%d" % pos  
    driver.execute_script(js)  
    time.sleep(1)
    
    for element in driver.find_elements_by_xpath(xpath):
        img_url = element.get_attribute('src')
        
        # 保存圖片到指定路徑
        if img_url != None and not img_url in img_url_dic:
            img_url_dic[img_url] = ''  
            m += 1
            # print(img_url)
            ext = img_url.split('/')[-1]
            # print(ext)
            filename = str(m) + 'Maltese' + '_' + ext +'.jpg'
            print(filename)
            # 保存圖片
            urllib.request.urlretrieve(img_url, os.path.join(local_path , filename)) 
driver.close()
# Out:
# 1Maltese_94c83797bbb5e639.jpg
# 2Maltese_7c80f72209402532.jpg
# 3Maltese_7db924e2370186db.jpg
# 4Maltese_7ba7cd40a1ed63b7.jpg
# 5Maltese_b6621729bb80cefb.jpg
# 6Maltese_34beeb195d0ff73f.jpg
# 7Maltese_3a88d875b396808b.jpg
# 8Maltese_6568d4150eb387fb.jpg
# 9Maltese_0a13782c48db9619.jpg
# 10Maltese_57166cf14dfc53fb.jpg
# 11Maltese_f1b4f8aafbfb0ee4.jpg
# 12Maltese_94dd1da88e1adb04.jpg
# 13Maltese_7151312b864a8f27.jpg
# 14Maltese_d3832bcd058b2ff1.jpg
# 15Maltese_3277ee77eaf8e220.jpg
# 16Maltese_0b9bf698f51e7ddd.jpg
# 17Maltese_32f4a1d419cd95a2.jpg
# 18Maltese_fab6a56021a98fe0.jpg
# 19Maltese_d3d9d345d6bc87e5.jpg
# 20Maltese_2ddec90322fe6b17.jpg
# 21Maltese_f9e805a1c0c0cccd.jpg
# 22Maltese_e3c0ea6685c36d32.jpg
# 23Maltese_983e73677077cb91.jpg
# 24Maltese_491ebe9897ef51aa.jpg
# 25Maltese_358ca10760eacbff.jpg
# 26Maltese_08e710f5cf182308.jpg
# 27Maltese_43a2ff67c94bc49b.jpg
# 28Maltese_e133a7a0328ab68b.jpg
# 29Maltese_fc1f0a898fff104b.jpg
# 30Maltese_4d16e2804c5bfe0b.jpg
# ...
